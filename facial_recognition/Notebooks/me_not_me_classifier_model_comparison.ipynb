# %%
import os
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# Set Some Parameters

# %%
#Dataset information

#Test dataset is set explicitly, because the amount of data is very small
train_aug_image_folder = os.path.join ('datasets', 'face_dataset_train_aug_images')
train_image_folder = os.path.join('datasets', 'face_dataset_train_images')
test_image_folder = os.path.join('datasets', 'face_dataset_test_images')
img_height, img_width= 250,250 #size of images
num_classes = 2 #number of classes

#training settings
validation_ratio = 0.15 #15% for the validation
batch_size = 16

AUTOTUNE = tf.data.AUTOTUNE

# %% [markdown]
# Create Dataset
#
# Read datasetrs from folders

# %%
#Train and validation sets of initial dataset
train_ds = keras.preprocessing.image_dataset_from_directory(
    train_image_folder,
    validation_split=validation_ratio,
    subset="training",
    seed=42,
    image_size=(img_height,img_width),
    label_mode='categorical',
    batch_size=batch_size,
    shuffle=True   
)

val_ds = keras.preprocessing.image_dataset_from_directory(
    train_image_folder,
    validation_split=validation_ratio,
    subset="validation",
    seed=42,
    image_size=(img_height,img_width),
    batch_size=batch_size,
    label_mode='categorical',
    shuffle=True
)
# Out:
# Found 433 files belonging to 2 classes.
# Using 369 files for training.
# Found 433 files belonging to 2 classes.
# Using 64 files for validation.

# %%
#train and validation sets of augmented dataset
train_aug_ds = keras.preprocessing.image_dataset_from_directory(
    train_aug_image_folder,
    validation_split=validation_ratio,
    subset="training",
    seed=42,
    image_size=(img_height,img_width),
    label_mode='categorical',
    batch_size=batch_size,
    shuffle=True
)
val_aug_ds = keras.preprocessing.image_dataset_from_directory(
    train_aug_image_folder,
    validation_split=validation_ratio,
    subset='validation',
    seed=42,
    image_size=(img_height,img_width),
    batch_size=batch_size,
    label_mode='categorical',
    shuffle=True
)
# Out:
# Found 695 files belonging to 2 classes.
# Using 591 files for training.
# Found 695 files belonging to 2 classes.
# Using 104 files for validation.

# %%
test_ds = keras.preprocessing.image_dataset_from_directory(
    test_image_folder,
    image_size=(img_height,img_width),
    label_mode='categorical',
    shuffle=False
)
# Out:
# Found 339 files belonging to 2 classes.

# %%
class_names = test_ds.class_names
class_names
# Out:
# ['me', 'not_me']

# %% [markdown]
# Buld The Model

# %%
# Here I experiment with different models
# Each model is represented in it own cells

# %% [markdown]
# VGG16

# %%
base_model = keras.applications.vgg16.VGG16(weights='imagenet',
                                            include_top=False, #without dense part of the network
                                            input_shape=(img_height,img_width, 3))

#set Layers to non-trainable
for layer in base_model.layers:
    layer.trainable = False
    
#add custom layers on top of the convolutional layers of VGG16
flatten = keras.layers.Flatten()(base_model.output)
dense_4096_1 = keras.layers.Dense(4096, activation='relu')(flatten)
dense_4096_2 = keras.layers.Dense(4096, activation='relu')(dense_4096_1)
output = keras.layers.Dense(num_classes, activation = 'sigmoid')(dense_4096_2)

VGG16 = keras.models.Model(inputs = base_model.input, outputs= output, name = 'VGG16')
VGG16.summary()
# Out:
# Model: "VGG16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 250, 250, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 250, 250, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 250, 250, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 125, 125, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 125, 125, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 125, 125, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 62, 62, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 62, 62, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 62, 62, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 62, 62, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 31, 31, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 31, 31, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 31, 31, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 31, 31, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 15, 15, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4096)              102764544
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 2)                 8194
#
# =================================================================
# Total params: 134,268,738
# Trainable params: 119,554,050
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ResNet50

# %%
base_model = keras.applications.ResNet50(weights='imagenet',
                                          include_top = False, #without dense part of the network
                                          input_shape=(img_height, img_width, 3))

#set layers to non-trainable
for layer in base_model.layers:
    layer.trainable = False

#add custom layers on top of ResNet
global_avg_pooling = keras.layers.GlobalAveragePooling2D()(base_model.output)
output = keras.layers.Dense(num_classes, activation = 'sigmoid')(global_avg_pooling)

ResNet50 = keras.models.Model(inputs = base_model.input, outputs= output, name = 'ResNet50')

ResNet50.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 250, 250, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 256, 256, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 125, 125, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 125, 125, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 125, 125, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 127, 127, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 63, 63, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 63, 63, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 63, 63, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 63, 63, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 63, 63, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 63, 63, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 63, 63, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 63, 63, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 63, 63, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 63, 63, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 63, 63, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 63, 63, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 63, 63, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 63, 63, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 63, 63, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 63, 63, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 63, 63, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 32, 32, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 32, 32, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 32, 32, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 32, 32, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 32, 32, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 32, 32, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 16, 16, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 16, 16, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 16, 16, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 16, 16, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 16, 16, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 16, 16, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 16, 16, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 16, 16, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 8, 8, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 8, 8, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 8, 8, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 8, 8, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 8, 8, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 8, 8, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 8, 8, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 8, 8, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 8, 8, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 8, 8, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 8, 8, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 8, 8, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 8, 8, 2048)   0           ['conv5_block3_add[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            4098        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 23,591,810
# Trainable params: 4,098
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %% [markdown]
# ResNet152

# %%
base_model = keras.applications.ResNet152(weights = 'imagenet',
                                          include_top= False, #without dense part of the network
                                          input_shape=(img_height,img_width,3))

#set layers to non-trainable
for layer in base_model.layers:
    layer.trainable = False

#add custom layers on top of ResNet
global_avg_pooling = keras.layers.GlobalAveragePooling2D()(base_model.output)
output = keras.layers.Dense(num_classes, activation='sigmoid')(global_avg_pooling)

ResNet152 = keras.models.Model(inputs = base_model.input,
                               outputs = output,
                               name = 'ResNet152')

ResNet152.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 [==============================] - 59s 0us/step
# Model: "ResNet152"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 250, 250, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 256, 256, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 125, 125, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 125, 125, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 125, 125, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 127, 127, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 63, 63, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 63, 63, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 63, 63, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 63, 63, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 63, 63, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 63, 63, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 63, 63, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 63, 63, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 63, 63, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 63, 63, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 63, 63, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 63, 63, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 63, 63, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 63, 63, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 63, 63, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 63, 63, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 63, 63, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 63, 63, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 32, 32, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 32, 32, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 32, 32, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 32, 32, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 32, 32, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 32, 32, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv3_block5_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block4_out[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block5_2_conv[0][0]']
#  ization)
#
#  conv3_block5_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block5_2_bn[0][0]']
#  n)
#
#  conv3_block5_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block5_2_relu[0][0]']
#
#  conv3_block5_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block5_3_conv[0][0]']
#  ization)
#
#  conv3_block5_add (Add)         (None, 32, 32, 512)  0           ['conv3_block4_out[0][0]',
#                                                                   'conv3_block5_3_bn[0][0]']
#
#  conv3_block5_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block5_add[0][0]']
#
#  conv3_block6_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block5_out[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block6_2_conv[0][0]']
#  ization)
#
#  conv3_block6_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block6_2_bn[0][0]']
#  n)
#
#  conv3_block6_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block6_2_relu[0][0]']
#
#  conv3_block6_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block6_3_conv[0][0]']
#  ization)
#
#  conv3_block6_add (Add)         (None, 32, 32, 512)  0           ['conv3_block5_out[0][0]',
#                                                                   'conv3_block6_3_bn[0][0]']
#
#  conv3_block6_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block6_add[0][0]']
#
#  conv3_block7_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block6_out[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block7_2_conv[0][0]']
#  ization)
#
#  conv3_block7_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block7_2_bn[0][0]']
#  n)
#
#  conv3_block7_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block7_2_relu[0][0]']
#
#  conv3_block7_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block7_3_conv[0][0]']
#  ization)
#
#  conv3_block7_add (Add)         (None, 32, 32, 512)  0           ['conv3_block6_out[0][0]',
#                                                                   'conv3_block7_3_bn[0][0]']
#
#  conv3_block7_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block7_add[0][0]']
#
#  conv3_block8_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block7_out[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block8_2_conv[0][0]']
#  ization)
#
#  conv3_block8_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block8_2_bn[0][0]']
#  n)
#
#  conv3_block8_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block8_2_relu[0][0]']
#
#  conv3_block8_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block8_3_conv[0][0]']
#  ization)
#
#  conv3_block8_add (Add)         (None, 32, 32, 512)  0           ['conv3_block7_out[0][0]',
#                                                                   'conv3_block8_3_bn[0][0]']
#
#  conv3_block8_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block8_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 16, 16, 256)  131328      ['conv3_block8_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 16, 16, 1024  525312      ['conv3_block8_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 16, 16, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 16, 16, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 16, 16, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 16, 16, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 16, 16, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
# ...
#
#  conv4_block34_3_conv (Conv2D)  (None, 16, 16, 1024  263168      ['conv4_block34_2_relu[0][0]']
#                                 )
#
#  conv4_block34_3_bn (BatchNorma  (None, 16, 16, 1024  4096       ['conv4_block34_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block34_add (Add)        (None, 16, 16, 1024  0           ['conv4_block33_out[0][0]',
#                                 )                                 'conv4_block34_3_bn[0][0]']
#
#  conv4_block34_out (Activation)  (None, 16, 16, 1024  0          ['conv4_block34_add[0][0]']
#                                 )
#
#  conv4_block35_1_conv (Conv2D)  (None, 16, 16, 256)  262400      ['conv4_block34_out[0][0]']
#
#  conv4_block35_1_bn (BatchNorma  (None, 16, 16, 256)  1024       ['conv4_block35_1_conv[0][0]']
#  lization)
#
#  conv4_block35_1_relu (Activati  (None, 16, 16, 256)  0          ['conv4_block35_1_bn[0][0]']
#  on)
#
#  conv4_block35_2_conv (Conv2D)  (None, 16, 16, 256)  590080      ['conv4_block35_1_relu[0][0]']
#
#  conv4_block35_2_bn (BatchNorma  (None, 16, 16, 256)  1024       ['conv4_block35_2_conv[0][0]']
#  lization)
#
#  conv4_block35_2_relu (Activati  (None, 16, 16, 256)  0          ['conv4_block35_2_bn[0][0]']
#  on)
#
#  conv4_block35_3_conv (Conv2D)  (None, 16, 16, 1024  263168      ['conv4_block35_2_relu[0][0]']
#                                 )
#
#  conv4_block35_3_bn (BatchNorma  (None, 16, 16, 1024  4096       ['conv4_block35_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block35_add (Add)        (None, 16, 16, 1024  0           ['conv4_block34_out[0][0]',
#                                 )                                 'conv4_block35_3_bn[0][0]']
#
#  conv4_block35_out (Activation)  (None, 16, 16, 1024  0          ['conv4_block35_add[0][0]']
#                                 )
#
#  conv4_block36_1_conv (Conv2D)  (None, 16, 16, 256)  262400      ['conv4_block35_out[0][0]']
#
#  conv4_block36_1_bn (BatchNorma  (None, 16, 16, 256)  1024       ['conv4_block36_1_conv[0][0]']
#  lization)
#
#  conv4_block36_1_relu (Activati  (None, 16, 16, 256)  0          ['conv4_block36_1_bn[0][0]']
#  on)
#
#  conv4_block36_2_conv (Conv2D)  (None, 16, 16, 256)  590080      ['conv4_block36_1_relu[0][0]']
#
#  conv4_block36_2_bn (BatchNorma  (None, 16, 16, 256)  1024       ['conv4_block36_2_conv[0][0]']
#  lization)
#
#  conv4_block36_2_relu (Activati  (None, 16, 16, 256)  0          ['conv4_block36_2_bn[0][0]']
#  on)
#
#  conv4_block36_3_conv (Conv2D)  (None, 16, 16, 1024  263168      ['conv4_block36_2_relu[0][0]']
#                                 )
#
#  conv4_block36_3_bn (BatchNorma  (None, 16, 16, 1024  4096       ['conv4_block36_3_conv[0][0]']
#  lization)                      )
#
#  conv4_block36_add (Add)        (None, 16, 16, 1024  0           ['conv4_block35_out[0][0]',
#                                 )                                 'conv4_block36_3_bn[0][0]']
#
#  conv4_block36_out (Activation)  (None, 16, 16, 1024  0          ['conv4_block36_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 8, 8, 512)    524800      ['conv4_block36_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 8, 8, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 8, 8, 2048)   2099200     ['conv4_block36_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 8, 8, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 8, 8, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 8, 8, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 8, 8, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 8, 8, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 8, 8, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 8, 8, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 8, 8, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 8, 8, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 8, 8, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 8, 8, 2048)   0           ['conv5_block3_add[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            4098        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 58,375,042
# Trainable params: 4,098
# Non-trainable params: 58,370,944
# __________________________________________________________________________________________________

# %% [markdown]
# Xception

# %%
base_model = keras.applications.Xception(weights = 'imagenet',
                                          include_top= False, #without dense part of the network
                                          input_shape=(img_height,img_width,3))
#set layers to non-trainable
for layer in base_model.layers:
    layer.trainable = False

#add custom layers on top of Xception
global_avg_pooling = keras.layers.GlobalAveragePooling2D()(base_model.output)
output= keras.layers.Dense(num_classes, activation='sigmoid')(global_avg_pooling)

Xception= keras.models.Model(inputs = base_model.input,
                             outputs= output,
                             name= 'Xception')

Xception.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 201s 2us/step
# Model: "Xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 250, 250, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 124, 124, 32  864         ['input_2[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 124, 124, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 124, 124, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 122, 122, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 122, 122, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 122, 122, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 122, 122, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 122, 122, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 122, 122, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 122, 122, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 122, 122, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d (Conv2D)                (None, 61, 61, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 61, 61, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 61, 61, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 61, 61, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 61, 61, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 61, 61, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 61, 61, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 61, 61, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 61, 61, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 61, 61, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 31, 31, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 31, 31, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 31, 31, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 31, 31, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 31, 31, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 31, 31, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 31, 31, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 31, 31, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 31, 31, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 31, 31, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 16, 16, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 16, 16, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 16, 16, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 16, 16, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 16, 16, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 16, 16, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 16, 16, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 16, 16, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 16, 16, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 16, 16, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 16, 16, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 16, 16, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 8, 8, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 8, 8, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8, 8, 1024)  4096        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 8, 8, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 8, 8, 1536)  1582080     ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 8, 8, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 8, 8, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 8, 8, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 8, 8, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 8, 8, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['block14_sepconv2_act[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 2)            4098        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 20,865,578
# Trainable params: 4,098
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %% [markdown]
# MobileNet

# %%
base_model = keras.applications.MobileNet(weights = 'imagenet',
                                          include_top= False, #without dense part of the network
                                          input_shape=(img_height,img_width,3))

#set layers to non-trainable
for layer in base_model.layers:
    layer.trainable = False
    
#add custom layers on top of MobileNet
global_avg_pooling = keras.layers.GlobalAveragePooling2D()(base_model.output)
output = keras.layers.Dense(num_classes, activation='sigmoid')(global_avg_pooling)

MobileNet = keras.models.Model(inputs = base_model.input,
                               outputs=output,
                               name='MobileNet')

MobileNet.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 4s 0us/step
# Model: "MobileNet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 250, 250, 3)]     0
#
#  conv1 (Conv2D)              (None, 125, 125, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 125, 125, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 125, 125, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 125, 125, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 125, 125, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 125, 125, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 125, 125, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 125, 125, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 125, 125, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 126, 126, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 62, 62, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 62, 62, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 62, 62, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 62, 62, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 62, 62, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 62, 62, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 62, 62, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 62, 62, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 62, 62, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 62, 62, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 62, 62, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 62, 62, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 63, 63, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 31, 31, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 31, 31, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 31, 31, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 31, 31, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 31, 31, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 31, 31, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 31, 31, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 31, 31, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 31, 31, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 31, 31, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 31, 31, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 31, 31, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 32, 32, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 15, 15, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 15, 15, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 15, 15, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 15, 15, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 15, 15, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 15, 15, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 15, 15, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 15, 15, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 15, 15, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 15, 15, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 15, 15, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 15, 15, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 15, 15, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 15, 15, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 15, 15, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 15, 15, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 15, 15, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 15, 15, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 15, 15, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 15, 15, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 15, 15, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 15, 15, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 15, 15, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 15, 15, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 15, 15, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 15, 15, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 15, 15, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 15, 15, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 15, 15, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 15, 15, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 15, 15, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 15, 15, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 15, 15, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 15, 15, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 15, 15, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 15, 15, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 16, 16, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 7, 7, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  global_average_pooling2d_2   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 2)                 2050
#
# =================================================================
# Total params: 3,230,914
# Trainable params: 2,050
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %% [markdown]
# Training
#
# use one of the models
#
# then choose if want to train CNN on augmented dataset
#
# train_on_aug = True/False

# %%
face_classifier = MobileNet
face_classifier.summary() # to check that the model is chosen correctly

train_on_aug = False #train on augmented dataset

if train_on_aug:
    train_ds = train_aug_ds
    val_ds = val_aug_ds

if train_on_aug:
    name_to_save = f"models/face_classifier_{face_classifier.name}_aug.h5"
else:
    name_to_save = f"models/face_classifier_{face_classifier.name}.h5"
# Out:
# Model: "Xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 250, 250, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 124, 124, 32  864         ['input_2[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 124, 124, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 124, 124, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 122, 122, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 122, 122, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 122, 122, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 122, 122, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 122, 122, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 122, 122, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 122, 122, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 122, 122, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d (Conv2D)                (None, 61, 61, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 61, 61, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 61, 61, 128)  512        ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 61, 61, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 61, 61, 128)  0          ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 61, 61, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 61, 61, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 61, 61, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 61, 61, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 61, 61, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 31, 31, 256)  32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 31, 31, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 31, 31, 256)  1024       ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 31, 31, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 31, 31, 256)  0          ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 31, 31, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 31, 31, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 31, 31, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 31, 31, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 31, 31, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 16, 16, 728)  186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 16, 16, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 728)  2912       ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 16, 16, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 16, 16, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 16, 16, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 16, 16, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 16, 16, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 16, 16, 728)  0          ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 16, 16, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 16, 16, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 16, 16, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 16, 16, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 16, 16, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 16, 16, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 16, 16, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 16, 16, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 16, 16, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 16, 16, 728)  0          ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 16, 16, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 16, 16, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 16, 16, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 16, 16, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_3 (Conv2D)              (None, 8, 8, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 8, 8, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8, 8, 1024)  4096        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 8, 8, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 8, 8, 1536)  1582080     ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 8, 8, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 8, 8, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 8, 8, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 8, 8, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 8, 8, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['block14_sepconv2_act[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 2)            4098        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 20,865,578
# Trainable params: 4,098
# Non-trainable params: 20,861,480
# __________________________________________________________________________________________________

# %% [markdown]
# All models train in one context, so this part of the code is the same

# %%
# ModelCheckpoint to save model in case of interrupting the learning process
checkpoint = ModelCheckpoint(name_to_save,
                             monitor="val_loss",
                             mode="min",
                             save_best_only=True,
                             verbose=1)

# EarlyStopping to find best model with a large number of epochs
earlystop = EarlyStopping(monitor='val_loss',
                          restore_best_weights=True,
                          patience=5,  # number of epochs with no improvement after which training will be stopped
                          verbose=1)

callbacks = [earlystop, checkpoint]

# %%
face_classifier.compile(loss='categorical_crossentropy',
                        optimizer = keras.optimizers.Adam(learning_rate=0.01),
                        metrics =['accuracy'])

# %%
epochs = 50

# %%
history = face_classifier.fit(
    train_ds,
    epochs = epochs,
    callbacks=callbacks,
    validation_data=val_ds)

face_classifier.save(name_to_save)
# Out:
# Epoch 1/50
# 24/24 [==============================] - ETA: 0s - loss: 11.4613 - accuracy: 0.6504
# Epoch 1: val_loss improved from inf to 0.92349, saving model to models\face_classifier_Xception.h5
# 24/24 [==============================] - 32s 1s/step - loss: 11.4613 - accuracy: 0.6504 - val_loss: 0.9235 - val_accuracy: 0.9375
# Epoch 2/50
# 24/24 [==============================] - ETA: 0s - loss: 4.8281 - accuracy: 0.7805
# Epoch 2: val_loss did not improve from 0.92349
# 24/24 [==============================] - 27s 1s/step - loss: 4.8281 - accuracy: 0.7805 - val_loss: 4.1836 - val_accuracy: 0.7344
# Epoch 3/50
# 24/24 [==============================] - ETA: 0s - loss: 1.4225 - accuracy: 0.8835
# Epoch 3: val_loss did not improve from 0.92349
# 24/24 [==============================] - 29s 1s/step - loss: 1.4225 - accuracy: 0.8835 - val_loss: 1.2690 - val_accuracy: 0.9375
# Epoch 4/50
# 24/24 [==============================] - ETA: 0s - loss: 0.3404 - accuracy: 0.9621
# Epoch 4: val_loss did not improve from 0.92349
# 24/24 [==============================] - 26s 1s/step - loss: 0.3404 - accuracy: 0.9621 - val_loss: 1.0221 - val_accuracy: 0.9375
# Epoch 5/50
# 24/24 [==============================] - ETA: 0s - loss: 0.1076 - accuracy: 0.9783
# Epoch 5: val_loss did not improve from 0.92349
# 24/24 [==============================] - 30s 1s/step - loss: 0.1076 - accuracy: 0.9783 - val_loss: 1.1316 - val_accuracy: 0.9844
# Epoch 6/50
# 24/24 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9729Restoring model weights from the end of the best epoch: 1.
#
# Epoch 6: val_loss did not improve from 0.92349
# 24/24 [==============================] - 25s 1s/step - loss: 0.1544 - accuracy: 0.9729 - val_loss: 1.7349 - val_accuracy: 0.8906
# Epoch 6: early stopping

# %% [markdown]
# Testing

# %%
model_name = 'face_classifier_Xception.h5'
face_classifier = keras.models.load_model(f'models/{model_name}')

# %%
def test_image_classifier_with_folder(model, path, y_true, img_height = 250, img_width = 250, class_names=['me', 'not me']):
    '''
    Read all images from 'path' using tensorflow.keras.preprocessing.image module,
    then classifies them using 'model' and compare result with 'y_true'.
    Calculate total accuracy based on 'path' test set
    
    parameters:
    model: Image classifier
    path(str): Path to the folder with images you want to test classifier on
    y_true: True label of the images in the folder. Must be in 'class_names' list
    img_height (int): The height of the image that the classifier can process
    img_width (int): The width of the image that the classifier can process
    class_names (array-like): List of class names
    
    Returns:
        None
    '''
    
    num_classes = len(class_names) # number of classes
    total = 0 # number of images total
    correct = 0 # number of images classified correctly
    
    for filename in os.listdir(path):
        #read each image in the folder and classifies it
        test_path = os.path.join(path,filename)
        test_image = keras.preprocessing.image.load_img( test_path, target_size=(img_height, img_width, 3))
        #from image to array, can try type (test_image)
        test_image = keras.preprocessing.image.img_to_array(test_image)
        #shape from (250,250,3) to (1,250,250,3)
        test_image = np.expand_dims(test_image, axis = 0)
        result = model.predict(test_image)
        
        y_pred = class_names[np.array(result[0]).argmax(axis=0)] # predicted class
        iscorrect = 'correct' if y_pred == y_true else 'incorrect'
        print('{} - {}'.format(iscorrect, filename))
        for index in range(num_classes):
            print("\t{:6} with probability of {:.2f}%".format(class_names[index], result[0][index]*100))
            
        total += 1
        if y_pred == y_true:
            correct +=1
        print("\n total accuracy is {:.2f}% = {}/{} samples classified correctly".format(correct/total*100, correct, total))

# %%
test_image_classifier_with_folder(face_classifier,'datasets/face_dataset_test_images/me', y_true = 'me')
# Out:
# 1/1 [==============================] - 1s 886ms/step
# correct - IMG_9208.JPG
# 	me     with probability of 94.25%
# 	not me with probability of 0.00%
#
#  total accuracy is 100.00% = 1/1 samples classified correctly
# 1/1 [==============================] - 0s 146ms/step
# correct - IMG_9209.JPG
# 	me     with probability of 99.99%
# 	not me with probability of 0.00%
#
#  total accuracy is 100.00% = 2/2 samples classified correctly
# 1/1 [==============================] - 0s 160ms/step
# correct - IMG_9210.JPG
# 	me     with probability of 100.00%
# 	not me with probability of 0.00%
#
#  total accuracy is 100.00% = 3/3 samples classified correctly
# 1/1 [==============================] - 0s 128ms/step
# correct - IMG_9211.JPG
# 	me     with probability of 99.99%
# 	not me with probability of 0.00%
#
#  total accuracy is 100.00% = 4/4 samples classified correctly
# 1/1 [==============================] - 0s 175ms/step
# incorrect - IMG_9212.JPG
# 	me     with probability of 3.10%
# 	not me with probability of 64.46%
#
#  total accuracy is 80.00% = 4/5 samples classified correctly
# 1/1 [==============================] - 0s 128ms/step
# incorrect - IMG_9213.JPG
# 	me     with probability of 7.08%
# 	not me with probability of 20.01%
#
#  total accuracy is 66.67% = 4/6 samples classified correctly
# 1/1 [==============================] - 0s 103ms/step
# incorrect - IMG_9214.JPG
# 	me     with probability of 0.08%
# 	not me with probability of 88.79%
#
#  total accuracy is 57.14% = 4/7 samples classified correctly
# 1/1 [==============================] - 0s 118ms/step
# incorrect - IMG_9215.JPG
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 50.00% = 4/8 samples classified correctly
# 1/1 [==============================] - 0s 107ms/step
# correct - IMG_9216.JPG
# 	me     with probability of 2.32%
# 	not me with probability of 0.00%
#
#  total accuracy is 55.56% = 5/9 samples classified correctly
# 1/1 [==============================] - 0s 104ms/step
# correct - IMG_9217.JPG
# 	me     with probability of 99.78%
# 	not me with probability of 0.06%
#
#  total accuracy is 60.00% = 6/10 samples classified correctly
# 1/1 [==============================] - 0s 115ms/step
# correct - IMG_9218.JPG
# 	me     with probability of 99.93%
# 	not me with probability of 0.12%
#
#  total accuracy is 63.64% = 7/11 samples classified correctly
# 1/1 [==============================] - 0s 112ms/step
# correct - IMG_9219.JPG
# 	me     with probability of 99.94%
# 	not me with probability of 0.04%
#
#  total accuracy is 66.67% = 8/12 samples classified correctly
# 1/1 [==============================] - 0s 103ms/step
# correct - IMG_9220.JPG
# 	me     with probability of 99.94%
# 	not me with probability of 0.00%
#
#  total accuracy is 69.23% = 9/13 samples classified correctly
# 1/1 [==============================] - 0s 111ms/step
# correct - IMG_9221.JPG
# 	me     with probability of 99.94%
# 	not me with probability of 0.00%
#
#  total accuracy is 71.43% = 10/14 samples classified correctly
# 1/1 [==============================] - 0s 131ms/step
# correct - IMG_9222.JPG
# 	me     with probability of 99.78%
# 	not me with probability of 0.06%
#
#  total accuracy is 73.33% = 11/15 samples classified correctly
# 1/1 [==============================] - 0s 107ms/step
# correct - IMG_9223.JPG
# 	me     with probability of 99.78%
# 	not me with probability of 0.06%
#
#  total accuracy is 75.00% = 12/16 samples classified correctly
# 1/1 [==============================] - 0s 93ms/step
# correct - IMG_9224.JPG
# 	me     with probability of 99.93%
# 	not me with probability of 0.12%
#
#  total accuracy is 76.47% = 13/17 samples classified correctly
# 1/1 [==============================] - 0s 98ms/step
# correct - IMG_9225.JPG
# 	me     with probability of 99.93%
# 	not me with probability of 0.12%
#
#  total accuracy is 77.78% = 14/18 samples classified correctly
# 1/1 [==============================] - 0s 172ms/step
# correct - IMG_9226.JPG
# 	me     with probability of 99.94%
# 	not me with probability of 0.04%
#
#  total accuracy is 78.95% = 15/19 samples classified correctly
# 1/1 [==============================] - 0s 91ms/step
# correct - IMG_9227.JPG
# 	me     with probability of 99.94%
# 	not me with probability of 0.04%
#
#  total accuracy is 80.00% = 16/20 samples classified correctly
# 1/1 [==============================] - 0s 97ms/step
# correct - IMG_9228.JPG
# 	me     with probability of 99.94%
# 	not me with probability of 0.00%
#
#  total accuracy is 80.95% = 17/21 samples classified correctly
# 1/1 [==============================] - 0s 115ms/step
# correct - IMG_9229.JPG
# 	me     with probability of 99.93%
# 	not me with probability of 0.12%
#
#  total accuracy is 81.82% = 18/22 samples classified correctly
# 1/1 [==============================] - 0s 91ms/step
# correct - IMG_9230.JPG
# 	me     with probability of 99.94%
# 	not me with probability of 0.04%
#
#  total accuracy is 82.61% = 19/23 samples classified correctly
# 1/1 [==============================] - 0s 92ms/step
# correct - IMG_9231.JPG
# 	me     with probability of 99.94%
# 	not me with probability of 0.00%
#
#  total accuracy is 83.33% = 20/24 samples classified correctly
# 1/1 [==============================] - 0s 101ms/step
# correct - IMG_9232.JPG
# 	me     with probability of 99.68%
# 	not me with probability of 0.13%
#
#  total accuracy is 84.00% = 21/25 samples classified correctly
# 1/1 [==============================] - 0s 92ms/step
# correct - IMG_9233.JPG
# 	me     with probability of 99.99%
# 	not me with probability of 0.11%
#
#  total accuracy is 84.62% = 22/26 samples classified correctly
# 1/1 [==============================] - 0s 96ms/step
# correct - IMG_9234.JPG
# 	me     with probability of 99.98%
# 	not me with probability of 0.24%
#
#  total accuracy is 85.19% = 23/27 samples classified correctly
# 1/1 [==============================] - 0s 107ms/step
# correct - IMG_9235.JPG
# 	me     with probability of 99.99%
# 	not me with probability of 0.00%
#
#  total accuracy is 85.71% = 24/28 samples classified correctly
# 1/1 [==============================] - 0s 108ms/step
# correct - IMG_9236.JPG
# 	me     with probability of 99.99%
# 	not me with probability of 0.00%
#
#  total accuracy is 86.21% = 25/29 samples classified correctly
# 1/1 [==============================] - 0s 93ms/step
# correct - IMG_9237.JPG
# 	me     with probability of 100.00%
# 	not me with probability of 0.00%
#
#  total accuracy is 86.67% = 26/30 samples classified correctly
# 1/1 [==============================] - 0s 91ms/step
# correct - IMG_9238.JPG
# 	me     with probability of 99.93%
# 	not me with probability of 0.00%
#
#  total accuracy is 87.10% = 27/31 samples classified correctly
# 1/1 [==============================] - 0s 91ms/step
# correct - IMG_9239.JPG
# 	me     with probability of 99.86%
# 	not me with probability of 0.00%
#
#  total accuracy is 87.50% = 28/32 samples classified correctly
# 1/1 [==============================] - 0s 99ms/step
# correct - IMG_9240.JPG
# 	me     with probability of 77.20%
# 	not me with probability of 0.63%
#
#  total accuracy is 87.88% = 29/33 samples classified correctly
# 1/1 [==============================] - 0s 186ms/step
# correct - IMG_9241.JPG
# 	me     with probability of 82.24%
# 	not me with probability of 0.12%
#
#  total accuracy is 88.24% = 30/34 samples classified correctly
# 1/1 [==============================] - 0s 90ms/step
# correct - IMG_9242.JPG
# 	me     with probability of 71.31%
# 	not me with probability of 0.64%
#
#  total accuracy is 88.57% = 31/35 samples classified correctly
# 1/1 [==============================] - 0s 111ms/step
# correct - IMG_9243.JPG
# 	me     with probability of 68.28%
# 	not me with probability of 1.04%
#
#  total accuracy is 88.89% = 32/36 samples classified correctly
# 1/1 [==============================] - 0s 100ms/step
# correct - IMG_9244.JPG
# 	me     with probability of 90.34%
# 	not me with probability of 0.03%
#
#  total accuracy is 89.19% = 33/37 samples classified correctly
# 1/1 [==============================] - 0s 97ms/step
# correct - IMG_9245.JPG
# 	me     with probability of 94.45%
# 	not me with probability of 0.12%
#
#  total accuracy is 89.47% = 34/38 samples classified correctly
# 1/1 [==============================] - 0s 112ms/step
# correct - IMG_9246.JPG
# 	me     with probability of 96.74%
# 	not me with probability of 0.03%
#
#  total accuracy is 89.74% = 35/39 samples classified correctly
# 1/1 [==============================] - 0s 98ms/step
# correct - IMG_9247.JPG
# 	me     with probability of 99.30%
# 	not me with probability of 0.00%
#
#  total accuracy is 90.00% = 36/40 samples classified correctly
# 1/1 [==============================] - 0s 143ms/step
# correct - IMG_9248.JPG
# 	me     with probability of 98.45%
# 	not me with probability of 0.01%
#
#  total accuracy is 90.24% = 37/41 samples classified correctly
# 1/1 [==============================] - 0s 103ms/step
# correct - IMG_9249.JPG
# 	me     with probability of 99.90%
# 	not me with probability of 0.00%
#
#  total accuracy is 90.48% = 38/42 samples classified correctly
# 1/1 [==============================] - 0s 104ms/step
# correct - IMG_9253.JPG
# 	me     with probability of 21.50%
# 	not me with probability of 2.01%
#
#  total accuracy is 90.70% = 39/43 samples classified correctly
# 1/1 [==============================] - 0s 108ms/step
# correct - IMG_9254.JPG
# 	me     with probability of 26.74%
# 	not me with probability of 24.78%
#
#  total accuracy is 90.91% = 40/44 samples classified correctly
# 1/1 [==============================] - 0s 110ms/step
# incorrect - IMG_9255.JPG
# 	me     with probability of 0.77%
# 	not me with probability of 4.75%
#
#  total accuracy is 88.89% = 40/45 samples classified correctly

# %%
test_image_classifier_with_folder(face_classifier,'datasets/face_dataset_test_images/not_me', y_true = 'not_me')
# Out:
# 1/1 [==============================] - 0s 102ms/step
# incorrect - Aaron_Peirsol_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/1 samples classified correctly
# 1/1 [==============================] - 0s 315ms/step
# incorrect - Aaron_Peirsol_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/2 samples classified correctly
# 1/1 [==============================] - 0s 78ms/step
# incorrect - Aaron_Peirsol_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 0.46%
#
#  total accuracy is 0.00% = 0/3 samples classified correctly
# 1/1 [==============================] - 0s 91ms/step
# incorrect - Aaron_Peirsol_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.99%
#
#  total accuracy is 0.00% = 0/4 samples classified correctly
# 1/1 [==============================] - 0s 101ms/step
# incorrect - Abdel_Madi_Shabneh_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.38%
#
#  total accuracy is 0.00% = 0/5 samples classified correctly
# 1/1 [==============================] - 0s 98ms/step
# incorrect - Abdel_Nasser_Assidi_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/6 samples classified correctly
# 1/1 [==============================] - 0s 93ms/step
# incorrect - Abdel_Nasser_Assidi_0002.jpg
# 	me     with probability of 0.13%
# 	not me with probability of 99.41%
#
#  total accuracy is 0.00% = 0/7 samples classified correctly
# 1/1 [==============================] - 0s 99ms/step
# incorrect - Abdullah_Gul_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/8 samples classified correctly
# 1/1 [==============================] - 0s 109ms/step
# incorrect - Abdullah_Gul_0002.jpg
# 	me     with probability of 0.02%
# 	not me with probability of 99.56%
#
#  total accuracy is 0.00% = 0/9 samples classified correctly
# 1/1 [==============================] - 0s 113ms/step
# incorrect - Abdullah_Gul_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.92%
#
#  total accuracy is 0.00% = 0/10 samples classified correctly
# 1/1 [==============================] - 0s 104ms/step
# incorrect - Abdullah_Gul_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.98%
#
#  total accuracy is 0.00% = 0/11 samples classified correctly
# 1/1 [==============================] - 0s 118ms/step
# incorrect - Abdullah_Gul_0005.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/12 samples classified correctly
# 1/1 [==============================] - 0s 109ms/step
# incorrect - Abdullah_Gul_0006.jpg
# 	me     with probability of 0.52%
# 	not me with probability of 97.66%
#
#  total accuracy is 0.00% = 0/13 samples classified correctly
# 1/1 [==============================] - 0s 113ms/step
# incorrect - Abdullah_Gul_0007.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 87.86%
#
#  total accuracy is 0.00% = 0/14 samples classified correctly
# 1/1 [==============================] - 0s 114ms/step
# incorrect - Abdullah_Gul_0008.jpg
# 	me     with probability of 0.08%
# 	not me with probability of 0.63%
#
#  total accuracy is 0.00% = 0/15 samples classified correctly
# 1/1 [==============================] - 0s 106ms/step
# incorrect - Abdullah_Gul_0009.jpg
# 	me     with probability of 0.03%
# 	not me with probability of 88.77%
#
#  total accuracy is 0.00% = 0/16 samples classified correctly
# 1/1 [==============================] - 0s 195ms/step
# incorrect - Abdullah_Gul_0010.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/17 samples classified correctly
# 1/1 [==============================] - 0s 96ms/step
# incorrect - Abdullah_Gul_0011.jpg
# 	me     with probability of 0.06%
# 	not me with probability of 99.26%
#
#  total accuracy is 0.00% = 0/18 samples classified correctly
# 1/1 [==============================] - 0s 97ms/step
# incorrect - Abdullah_Gul_0012.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 93.93%
#
#  total accuracy is 0.00% = 0/19 samples classified correctly
# 1/1 [==============================] - 0s 93ms/step
# incorrect - Abdullah_Gul_0013.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/20 samples classified correctly
# 1/1 [==============================] - 0s 98ms/step
# incorrect - Abdullah_Gul_0014.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.85%
#
#  total accuracy is 0.00% = 0/21 samples classified correctly
# 1/1 [==============================] - 0s 100ms/step
# incorrect - Abdullah_Gul_0015.jpg
# 	me     with probability of 0.03%
# 	not me with probability of 0.40%
#
#  total accuracy is 0.00% = 0/22 samples classified correctly
# 1/1 [==============================] - 0s 98ms/step
# incorrect - Abdullah_Gul_0016.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.95%
#
#  total accuracy is 0.00% = 0/23 samples classified correctly
# 1/1 [==============================] - 0s 103ms/step
# incorrect - Abdullah_Gul_0017.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 38.92%
#
#  total accuracy is 0.00% = 0/24 samples classified correctly
# 1/1 [==============================] - 0s 95ms/step
# incorrect - Abdullah_Gul_0018.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/25 samples classified correctly
# 1/1 [==============================] - 0s 93ms/step
# incorrect - Abdullah_Gul_0019.jpg
# 	me     with probability of 0.05%
# 	not me with probability of 99.94%
#
#  total accuracy is 0.00% = 0/26 samples classified correctly
# 1/1 [==============================] - 0s 101ms/step
# incorrect - Abdullah_Nasseef_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/27 samples classified correctly
# 1/1 [==============================] - 0s 98ms/step
# incorrect - Adam_Mair_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/28 samples classified correctly
# 1/1 [==============================] - 0s 97ms/step
# incorrect - Adrian_McPherson_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.87%
#
#  total accuracy is 0.00% = 0/29 samples classified correctly
# 1/1 [==============================] - 0s 95ms/step
# incorrect - Adrian_McPherson_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.96%
#
#  total accuracy is 0.00% = 0/30 samples classified correctly
# 1/1 [==============================] - 0s 164ms/step
# incorrect - Ahmed_Ahmed_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/31 samples classified correctly
# 1/1 [==============================] - 0s 137ms/step
# incorrect - Aicha_El_Ouafi_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/32 samples classified correctly
# 1/1 [==============================] - 0s 91ms/step
# incorrect - Aicha_El_Ouafi_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/33 samples classified correctly
# 1/1 [==============================] - 0s 92ms/step
# incorrect - Aicha_El_Ouafi_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/34 samples classified correctly
# 1/1 [==============================] - 0s 91ms/step
# incorrect - Ai_Sugiyama_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/35 samples classified correctly
# 1/1 [==============================] - 0s 102ms/step
# incorrect - Ai_Sugiyama_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.90%
#
#  total accuracy is 0.00% = 0/36 samples classified correctly
# 1/1 [==============================] - 0s 109ms/step
# incorrect - Ai_Sugiyama_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/37 samples classified correctly
# 1/1 [==============================] - 0s 145ms/step
# incorrect - Ai_Sugiyama_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/38 samples classified correctly
# 1/1 [==============================] - 0s 114ms/step
# incorrect - Ai_Sugiyama_0005.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/39 samples classified correctly
# 1/1 [==============================] - 0s 117ms/step
# incorrect - Alan_Dreher_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/40 samples classified correctly
# 1/1 [==============================] - 0s 111ms/step
# incorrect - Alberto_Gonzales_0001.jpg
# 	me     with probability of 1.31%
# 	not me with probability of 42.11%
#
#  total accuracy is 0.00% = 0/41 samples classified correctly
# 1/1 [==============================] - 0s 133ms/step
# incorrect - Albert_Costa_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/42 samples classified correctly
# 1/1 [==============================] - 0s 129ms/step
# incorrect - Albert_Costa_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/43 samples classified correctly
# 1/1 [==============================] - 0s 181ms/step
# incorrect - Albert_Costa_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/44 samples classified correctly
# 1/1 [==============================] - 0s 213ms/step
# incorrect - Albert_Costa_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/45 samples classified correctly
# 1/1 [==============================] - 0s 95ms/step
# incorrect - Albert_Costa_0005.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/46 samples classified correctly
# 1/1 [==============================] - 0s 133ms/step
# incorrect - Albert_Costa_0006.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/47 samples classified correctly
# 1/1 [==============================] - 0s 100ms/step
# incorrect - Alicia_Keys_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/48 samples classified correctly
# 1/1 [==============================] - 0s 94ms/step
# incorrect - Alicia_Molik_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/49 samples classified correctly
# 1/1 [==============================] - 0s 99ms/step
# incorrect - Alicia_Silverstone_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 0.02%
#
#  total accuracy is 0.00% = 0/50 samples classified correctly
# 1/1 [==============================] - 0s 115ms/step
# incorrect - Alicia_Silverstone_0002.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 0.05%
#
#  total accuracy is 0.00% = 0/51 samples classified correctly
# 1/1 [==============================] - 0s 106ms/step
# incorrect - Ali_Naimi_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 0.01%
#
#  total accuracy is 0.00% = 0/52 samples classified correctly
# 1/1 [==============================] - 0s 111ms/step
# incorrect - Ali_Naimi_0002.jpg
# 	me     with probability of 0.02%
# 	not me with probability of 47.77%
#
#  total accuracy is 0.00% = 0/53 samples classified correctly
# 1/1 [==============================] - 0s 108ms/step
# incorrect - Ali_Naimi_0003.jpg
# 	me     with probability of 0.41%
# 	not me with probability of 32.74%
#
#  total accuracy is 0.00% = 0/54 samples classified correctly
# 1/1 [==============================] - 0s 108ms/step
# incorrect - Ali_Naimi_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/55 samples classified correctly
# 1/1 [==============================] - 0s 107ms/step
# incorrect - Ali_Naimi_0005.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/56 samples classified correctly
# 1/1 [==============================] - 0s 114ms/step
# incorrect - Ali_Naimi_0006.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.44%
#
#  total accuracy is 0.00% = 0/57 samples classified correctly
# 1/1 [==============================] - 0s 104ms/step
# incorrect - Ali_Naimi_0007.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/58 samples classified correctly
# 1/1 [==============================] - 0s 213ms/step
# incorrect - Ali_Naimi_0008.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/59 samples classified correctly
# 1/1 [==============================] - 0s 106ms/step
# incorrect - Al_Cardenas_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/60 samples classified correctly
# 1/1 [==============================] - 0s 108ms/step
# incorrect - Amanda_Marsh_0001.jpg
# 	me     with probability of 5.31%
# 	not me with probability of 0.00%
#
#  total accuracy is 0.00% = 0/61 samples classified correctly
# 1/1 [==============================] - 0s 105ms/step
# incorrect - Anders_Fogh_Rasmussen_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/62 samples classified correctly
# 1/1 [==============================] - 0s 105ms/step
# incorrect - Anders_Fogh_Rasmussen_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/63 samples classified correctly
# 1/1 [==============================] - 0s 112ms/step
# incorrect - Anders_Fogh_Rasmussen_0003.jpg
# 	me     with probability of 0.20%
# 	not me with probability of 3.22%
#
#  total accuracy is 0.00% = 0/64 samples classified correctly
# 1/1 [==============================] - 0s 107ms/step
# incorrect - Anders_Fogh_Rasmussen_0004.jpg
# 	me     with probability of 0.95%
# 	not me with probability of 0.00%
#
#  total accuracy is 0.00% = 0/65 samples classified correctly
# 1/1 [==============================] - 0s 110ms/step
# incorrect - Andrew_Weissmann_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.99%
#
#  total accuracy is 0.00% = 0/66 samples classified correctly
# 1/1 [==============================] - 0s 105ms/step
# incorrect - Andrew_Weissmann_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/67 samples classified correctly
# 1/1 [==============================] - 0s 113ms/step
# incorrect - Andrew_Weissmann_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/68 samples classified correctly
# 1/1 [==============================] - 0s 105ms/step
# incorrect - Andre_Agassi_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 75.68%
#
#  total accuracy is 0.00% = 0/69 samples classified correctly
# 1/1 [==============================] - 0s 158ms/step
# incorrect - Andre_Agassi_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/70 samples classified correctly
# 1/1 [==============================] - 0s 103ms/step
# incorrect - Andre_Agassi_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.99%
#
#  total accuracy is 0.00% = 0/71 samples classified correctly
# 1/1 [==============================] - 0s 110ms/step
# incorrect - Andre_Agassi_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/72 samples classified correctly
# 1/1 [==============================] - 0s 181ms/step
# incorrect - Andre_Agassi_0005.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.85%
#
#  total accuracy is 0.00% = 0/73 samples classified correctly
# 1/1 [==============================] - 0s 105ms/step
# incorrect - Andre_Agassi_0006.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 93.18%
#
#  total accuracy is 0.00% = 0/74 samples classified correctly
# 1/1 [==============================] - 0s 94ms/step
# incorrect - Andre_Agassi_0007.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/75 samples classified correctly
# 1/1 [==============================] - 0s 94ms/step
# incorrect - Andre_Agassi_0008.jpg
# 	me     with probability of 13.15%
# 	not me with probability of 0.12%
#
#  total accuracy is 0.00% = 0/76 samples classified correctly
# 1/1 [==============================] - 0s 124ms/step
# incorrect - Andre_Agassi_0009.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/77 samples classified correctly
# 1/1 [==============================] - 0s 188ms/step
# incorrect - Andre_Agassi_0010.jpg
# 	me     with probability of 84.30%
# 	not me with probability of 0.00%
#
#  total accuracy is 0.00% = 0/78 samples classified correctly
# 1/1 [==============================] - 0s 104ms/step
# incorrect - Andre_Agassi_0011.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 97.81%
#
#  total accuracy is 0.00% = 0/79 samples classified correctly
# 1/1 [==============================] - 0s 133ms/step
# incorrect - Andre_Agassi_0012.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/80 samples classified correctly
# 1/1 [==============================] - 0s 122ms/step
# incorrect - Andre_Agassi_0013.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/81 samples classified correctly
# 1/1 [==============================] - 0s 166ms/step
# incorrect - Andre_Agassi_0014.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/82 samples classified correctly
# 1/1 [==============================] - 0s 98ms/step
# incorrect - Andre_Agassi_0015.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/83 samples classified correctly
# 1/1 [==============================] - 0s 149ms/step
# incorrect - Andre_Agassi_0016.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/84 samples classified correctly
# 1/1 [==============================] - 0s 207ms/step
# incorrect - Andre_Agassi_0017.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/85 samples classified correctly
# 1/1 [==============================] - 0s 229ms/step
# incorrect - Andre_Agassi_0018.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/86 samples classified correctly
# 1/1 [==============================] - 0s 269ms/step
# incorrect - Andre_Agassi_0019.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.94%
#
#  total accuracy is 0.00% = 0/87 samples classified correctly
# 1/1 [==============================] - 0s 270ms/step
# incorrect - Andre_Agassi_0020.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.98%
#
#  total accuracy is 0.00% = 0/88 samples classified correctly
# 1/1 [==============================] - 0s 334ms/step
# incorrect - Andre_Agassi_0021.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/89 samples classified correctly
# 1/1 [==============================] - 0s 202ms/step
# incorrect - Andre_Agassi_0022.jpg
# 	me     with probability of 0.02%
# 	not me with probability of 95.52%
#
#  total accuracy is 0.00% = 0/90 samples classified correctly
# 1/1 [==============================] - 0s 170ms/step
# incorrect - Andre_Agassi_0023.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/91 samples classified correctly
# 1/1 [==============================] - 0s 358ms/step
# incorrect - Andre_Agassi_0024.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/92 samples classified correctly
# 1/1 [==============================] - 0s 157ms/step
# incorrect - Andre_Agassi_0025.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/93 samples classified correctly
# 1/1 [==============================] - 0s 123ms/step
# incorrect - Andre_Agassi_0026.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/94 samples classified correctly
# 1/1 [==============================] - 0s 129ms/step
# incorrect - Andre_Agassi_0027.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/95 samples classified correctly
# 1/1 [==============================] - 0s 126ms/step
# incorrect - Andre_Agassi_0028.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/96 samples classified correctly
# 1/1 [==============================] - 0s 99ms/step
# incorrect - Andre_Agassi_0029.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/97 samples classified correctly
# 1/1 [==============================] - 0s 116ms/step
# incorrect - Andre_Agassi_0030.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.51%
#
#  total accuracy is 0.00% = 0/98 samples classified correctly
# 1/1 [==============================] - 0s 100ms/step
# incorrect - Andre_Agassi_0031.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/99 samples classified correctly
# 1/1 [==============================] - 0s 98ms/step
# incorrect - Andre_Agassi_0032.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/100 samples classified correctly
# 1/1 [==============================] - 0s 106ms/step
# incorrect - Andre_Agassi_0033.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/101 samples classified correctly
# 1/1 [==============================] - 0s 102ms/step
# incorrect - Andre_Agassi_0034.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/102 samples classified correctly
# 1/1 [==============================] - 0s 110ms/step
# incorrect - Andre_Agassi_0035.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/103 samples classified correctly
# 1/1 [==============================] - 0s 132ms/step
# incorrect - Andre_Agassi_0036.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/104 samples classified correctly
# 1/1 [==============================] - 0s 253ms/step
# incorrect - Angela_Lansbury_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 67.15%
#
#  total accuracy is 0.00% = 0/105 samples classified correctly
# 1/1 [==============================] - 0s 229ms/step
# incorrect - Angela_Lansbury_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/106 samples classified correctly
# 1/1 [==============================] - 0s 142ms/step
# incorrect - Anna_Jones_0001.jpg
# 	me     with probability of 5.20%
# 	not me with probability of 0.00%
#
#  total accuracy is 0.00% = 0/107 samples classified correctly
# 1/1 [==============================] - 0s 120ms/step
# incorrect - Anthony_Pico_0001.jpg
# 	me     with probability of 0.02%
# 	not me with probability of 7.21%
#
#  total accuracy is 0.00% = 0/108 samples classified correctly
# 1/1 [==============================] - 0s 165ms/step
# incorrect - Antonio_Cassano_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/109 samples classified correctly
# 1/1 [==============================] - 0s 148ms/step
# incorrect - Ashley_Postell_0001.jpg
# 	me     with probability of 0.04%
# 	not me with probability of 0.81%
#
#  total accuracy is 0.00% = 0/110 samples classified correctly
# 1/1 [==============================] - 0s 105ms/step
# incorrect - Basdeo_Panday_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/111 samples classified correctly
# 1/1 [==============================] - 0s 138ms/step
# incorrect - Bob_Hartley_0001.jpg
# 	me     with probability of 0.02%
# 	not me with probability of 39.54%
#
#  total accuracy is 0.00% = 0/112 samples classified correctly
# 1/1 [==============================] - 0s 98ms/step
# incorrect - Bob_Holden_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 96.12%
#
#  total accuracy is 0.00% = 0/113 samples classified correctly
# 1/1 [==============================] - 0s 191ms/step
# incorrect - Brandon_Hammond_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/114 samples classified correctly
# 1/1 [==============================] - 0s 282ms/step
# incorrect - Bruce_Van_De_Velde_0001.jpg
# 	me     with probability of 6.04%
# 	not me with probability of 1.94%
#
#  total accuracy is 0.00% = 0/115 samples classified correctly
# 1/1 [==============================] - 0s 111ms/step
# incorrect - Bruce_Van_De_Velde_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/116 samples classified correctly
# 1/1 [==============================] - 0s 247ms/step
# incorrect - Bruce_Weber_0001.jpg
# 	me     with probability of 34.61%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/117 samples classified correctly
# 1/1 [==============================] - 0s 184ms/step
# incorrect - Bruce_Weber_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 24.72%
#
#  total accuracy is 0.00% = 0/118 samples classified correctly
# 1/1 [==============================] - 0s 134ms/step
# incorrect - Calista_Flockhart_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.50%
#
#  total accuracy is 0.00% = 0/119 samples classified correctly
# 1/1 [==============================] - 0s 123ms/step
# incorrect - Calista_Flockhart_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 98.97%
#
#  total accuracy is 0.00% = 0/120 samples classified correctly
# 1/1 [==============================] - 0s 138ms/step
# incorrect - Calista_Flockhart_0003.jpg
# 	me     with probability of 2.87%
# 	not me with probability of 0.00%
#
#  total accuracy is 0.00% = 0/121 samples classified correctly
# 1/1 [==============================] - 0s 132ms/step
# incorrect - Calista_Flockhart_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/122 samples classified correctly
# 1/1 [==============================] - 0s 177ms/step
# incorrect - Calista_Flockhart_0005.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.87%
#
#  total accuracy is 0.00% = 0/123 samples classified correctly
# 1/1 [==============================] - 1s 546ms/step
# incorrect - Calista_Flockhart_0006.jpg
# 	me     with probability of 6.52%
# 	not me with probability of 0.00%
#
#  total accuracy is 0.00% = 0/124 samples classified correctly
# 1/1 [==============================] - 0s 293ms/step
# incorrect - Calvin_Harrison_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/125 samples classified correctly
# 1/1 [==============================] - 0s 134ms/step
# incorrect - Carla_Gay_Balingit_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/126 samples classified correctly
# 1/1 [==============================] - 0s 155ms/step
# incorrect - Carla_Gugino_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.99%
#
#  total accuracy is 0.00% = 0/127 samples classified correctly
# 1/1 [==============================] - 0s 107ms/step
# incorrect - Carlos_Lordkipanitse_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.99%
#
#  total accuracy is 0.00% = 0/128 samples classified correctly
# 1/1 [==============================] - 0s 100ms/step
# incorrect - Carlos_Ortega_0001.jpg
# 	me     with probability of 1.08%
# 	not me with probability of 0.09%
#
#  total accuracy is 0.00% = 0/129 samples classified correctly
# 1/1 [==============================] - 0s 99ms/step
# incorrect - Carlos_Ortega_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 98.78%
#
#  total accuracy is 0.00% = 0/130 samples classified correctly
# 1/1 [==============================] - 0s 101ms/step
# incorrect - Carlos_Ortega_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.79%
#
#  total accuracy is 0.00% = 0/131 samples classified correctly
# 1/1 [==============================] - 0s 166ms/step
# incorrect - Carrie-Anne_Moss_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 80.21%
#
#  total accuracy is 0.00% = 0/132 samples classified correctly
# 1/1 [==============================] - 0s 154ms/step
# incorrect - Carrie-Anne_Moss_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/133 samples classified correctly
# 1/1 [==============================] - 0s 122ms/step
# incorrect - Carrie-Anne_Moss_0003.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 15.61%
#
#  total accuracy is 0.00% = 0/134 samples classified correctly
# 1/1 [==============================] - 0s 259ms/step
# incorrect - Carrie-Anne_Moss_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 93.55%
#
#  total accuracy is 0.00% = 0/135 samples classified correctly
# 1/1 [==============================] - 0s 95ms/step
# incorrect - Carrie-Anne_Moss_0005.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/136 samples classified correctly
# 1/1 [==============================] - 0s 111ms/step
# incorrect - Carroll_Weimer_0001.jpg
# 	me     with probability of 80.38%
# 	not me with probability of 0.29%
#
#  total accuracy is 0.00% = 0/137 samples classified correctly
# 1/1 [==============================] - 0s 220ms/step
# incorrect - Cathy_Cunningham_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/138 samples classified correctly
# 1/1 [==============================] - 0s 311ms/step
# incorrect - Chadha_Gurinder_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 98.74%
#
#  total accuracy is 0.00% = 0/139 samples classified correctly
# 1/1 [==============================] - 0s 143ms/step
# incorrect - Charles_Pickering_0001.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 0.00%
#
#  total accuracy is 0.00% = 0/140 samples classified correctly
# 1/1 [==============================] - 0s 141ms/step
# incorrect - Christopher_Whittle_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/141 samples classified correctly
# 1/1 [==============================] - 0s 141ms/step
# incorrect - Chris_Rock_0001.jpg
# 	me     with probability of 0.50%
# 	not me with probability of 99.94%
#
#  total accuracy is 0.00% = 0/142 samples classified correctly
# 1/1 [==============================] - 0s 185ms/step
# incorrect - Chris_Rock_0002.jpg
# 	me     with probability of 0.05%
# 	not me with probability of 79.33%
#
#  total accuracy is 0.00% = 0/143 samples classified correctly
# 1/1 [==============================] - 0s 433ms/step
# incorrect - Collis_Temple_III_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.96%
#
#  total accuracy is 0.00% = 0/144 samples classified correctly
# 1/1 [==============================] - 0s 123ms/step
# incorrect - Dariusz_Michalczewski_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 80.48%
#
#  total accuracy is 0.00% = 0/145 samples classified correctly
# 1/1 [==============================] - 0s 105ms/step
# incorrect - David_Ballantyne_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/146 samples classified correctly
# 1/1 [==============================] - 0s 93ms/step
# incorrect - David_Leahy_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/147 samples classified correctly
# 1/1 [==============================] - 0s 107ms/step
# incorrect - David_Leahy_0002.jpg
# 	me     with probability of 0.53%
# 	not me with probability of 50.47%
#
#  total accuracy is 0.00% = 0/148 samples classified correctly
# 1/1 [==============================] - 0s 131ms/step
# incorrect - David_Sousa_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/149 samples classified correctly
# 1/1 [==============================] - 0s 133ms/step
# incorrect - Davis_Love_III_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/150 samples classified correctly
# 1/1 [==============================] - 0s 102ms/step
# incorrect - Dennis_Kucinich_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/151 samples classified correctly
# 1/1 [==============================] - 0s 104ms/step
# incorrect - Dennis_Kucinich_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/152 samples classified correctly
# 1/1 [==============================] - 0s 122ms/step
# incorrect - Dennis_Kucinich_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.99%
#
#  total accuracy is 0.00% = 0/153 samples classified correctly
# 1/1 [==============================] - 0s 88ms/step
# incorrect - Dennis_Kucinich_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/154 samples classified correctly
# 1/1 [==============================] - 0s 180ms/step
# incorrect - Dennis_Kucinich_0005.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/155 samples classified correctly
# 1/1 [==============================] - 0s 112ms/step
# incorrect - Dennis_Kucinich_0006.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 98.64%
#
#  total accuracy is 0.00% = 0/156 samples classified correctly
# 1/1 [==============================] - 0s 221ms/step
# incorrect - Dennis_Kucinich_0007.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 99.05%
#
#  total accuracy is 0.00% = 0/157 samples classified correctly
# 1/1 [==============================] - 0s 107ms/step
# incorrect - Dianne_Feinstein_0001.jpg
# 	me     with probability of 0.58%
# 	not me with probability of 99.99%
#
#  total accuracy is 0.00% = 0/158 samples classified correctly
# 1/1 [==============================] - 0s 104ms/step
# incorrect - Dianne_Feinstein_0002.jpg
# 	me     with probability of 0.38%
# 	not me with probability of 97.12%
#
#  total accuracy is 0.00% = 0/159 samples classified correctly
# 1/1 [==============================] - 0s 186ms/step
# incorrect - Dianne_Feinstein_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 93.66%
#
#  total accuracy is 0.00% = 0/160 samples classified correctly
# 1/1 [==============================] - 0s 112ms/step
# incorrect - Dianne_Reeves_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/161 samples classified correctly
# 1/1 [==============================] - 0s 97ms/step
# incorrect - Dick_Posthumus_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 0.00%
#
#  total accuracy is 0.00% = 0/162 samples classified correctly
# 1/1 [==============================] - 0s 109ms/step
# incorrect - Dionne_Warwick_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/163 samples classified correctly
# 1/1 [==============================] - 0s 183ms/step
# incorrect - Donna_Morrissey_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 98.33%
#
#  total accuracy is 0.00% = 0/164 samples classified correctly
# 1/1 [==============================] - 0s 140ms/step
# incorrect - Elizabeth_Dole_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 73.20%
#
#  total accuracy is 0.00% = 0/165 samples classified correctly
# 1/1 [==============================] - 0s 197ms/step
# incorrect - Elizabeth_Dole_0002.jpg
# 	me     with probability of 24.51%
# 	not me with probability of 0.01%
#
#  total accuracy is 0.00% = 0/166 samples classified correctly
# 1/1 [==============================] - 0s 148ms/step
# incorrect - Elizabeth_Dole_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/167 samples classified correctly
# 1/1 [==============================] - 0s 321ms/step
# incorrect - Elizabeth_Dole_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/168 samples classified correctly
# 1/1 [==============================] - 0s 108ms/step
# incorrect - Emily_Mortimer_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/169 samples classified correctly
# 1/1 [==============================] - 0s 107ms/step
# incorrect - Eric_Staal_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.99%
#
#  total accuracy is 0.00% = 0/170 samples classified correctly
# 1/1 [==============================] - 0s 105ms/step
# incorrect - Erskine_Bowles_0001.jpg
# 	me     with probability of 6.37%
# 	not me with probability of 0.00%
#
#  total accuracy is 0.00% = 0/171 samples classified correctly
# 1/1 [==============================] - 0s 104ms/step
# incorrect - Evan_Marriott_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/172 samples classified correctly
# 1/1 [==============================] - 0s 105ms/step
# incorrect - Fernando_Valenzuela_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 0.05%
#
#  total accuracy is 0.00% = 0/173 samples classified correctly
# 1/1 [==============================] - 0s 98ms/step
# incorrect - Franck_Cerutti_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/174 samples classified correctly
# 1/1 [==============================] - 0s 132ms/step
# incorrect - Gabriel_Batistuta_0001.jpg
# 	me     with probability of 0.34%
# 	not me with probability of 1.23%
#
#  total accuracy is 0.00% = 0/175 samples classified correctly
# 1/1 [==============================] - 0s 226ms/step
# incorrect - Gabriel_Batistuta_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.82%
#
#  total accuracy is 0.00% = 0/176 samples classified correctly
# 1/1 [==============================] - 0s 184ms/step
# incorrect - Garry_Kasparov_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 97.41%
#
#  total accuracy is 0.00% = 0/177 samples classified correctly
# 1/1 [==============================] - 0s 415ms/step
# incorrect - Garry_Kasparov_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 96.12%
#
#  total accuracy is 0.00% = 0/178 samples classified correctly
# 1/1 [==============================] - 0s 301ms/step
# incorrect - Gene_Keady_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.97%
#
#  total accuracy is 0.00% = 0/179 samples classified correctly
# 1/1 [==============================] - 0s 168ms/step
# incorrect - Gene_Robinson_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.97%
#
#  total accuracy is 0.00% = 0/180 samples classified correctly
# 1/1 [==============================] - 0s 201ms/step
# incorrect - Gene_Robinson_0002.jpg
# 	me     with probability of 12.78%
# 	not me with probability of 66.84%
#
#  total accuracy is 0.00% = 0/181 samples classified correctly
# 1/1 [==============================] - 0s 96ms/step
# incorrect - Gene_Robinson_0003.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 99.77%
#
#  total accuracy is 0.00% = 0/182 samples classified correctly
# 1/1 [==============================] - 0s 264ms/step
# incorrect - Gene_Robinson_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 9.78%
#
#  total accuracy is 0.00% = 0/183 samples classified correctly
# 1/1 [==============================] - 0s 164ms/step
# incorrect - Gene_Robinson_0005.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.94%
#
#  total accuracy is 0.00% = 0/184 samples classified correctly
# 1/1 [==============================] - 0s 162ms/step
# incorrect - George_Allen_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/185 samples classified correctly
# 1/1 [==============================] - 0s 101ms/step
# incorrect - George_HW_Bush_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/186 samples classified correctly
# 1/1 [==============================] - 0s 113ms/step
# incorrect - George_HW_Bush_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/187 samples classified correctly
# 1/1 [==============================] - 0s 134ms/step
# incorrect - George_HW_Bush_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/188 samples classified correctly
# 1/1 [==============================] - 0s 363ms/step
# incorrect - George_HW_Bush_0004.jpg
# 	me     with probability of 1.24%
# 	not me with probability of 0.31%
#
#  total accuracy is 0.00% = 0/189 samples classified correctly
# 1/1 [==============================] - 0s 169ms/step
# incorrect - George_HW_Bush_0005.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.50%
#
#  total accuracy is 0.00% = 0/190 samples classified correctly
# 1/1 [==============================] - 0s 128ms/step
# incorrect - George_HW_Bush_0006.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/191 samples classified correctly
# 1/1 [==============================] - 0s 111ms/step
# incorrect - George_HW_Bush_0007.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.99%
#
#  total accuracy is 0.00% = 0/192 samples classified correctly
# 1/1 [==============================] - 0s 156ms/step
# incorrect - George_HW_Bush_0008.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 60.83%
#
#  total accuracy is 0.00% = 0/193 samples classified correctly
# 1/1 [==============================] - 0s 135ms/step
# incorrect - George_HW_Bush_0009.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/194 samples classified correctly
# 1/1 [==============================] - 0s 101ms/step
# incorrect - George_HW_Bush_0010.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/195 samples classified correctly
# 1/1 [==============================] - 0s 121ms/step
# incorrect - George_HW_Bush_0011.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/196 samples classified correctly
# 1/1 [==============================] - 0s 142ms/step
# incorrect - George_HW_Bush_0012.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/197 samples classified correctly
# 1/1 [==============================] - 0s 119ms/step
# incorrect - George_HW_Bush_0013.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/198 samples classified correctly
# 1/1 [==============================] - 0s 131ms/step
# incorrect - George_McCloud_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/199 samples classified correctly
# 1/1 [==============================] - 0s 240ms/step
# incorrect - George_Plimpton_0001.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 0.54%
#
#  total accuracy is 0.00% = 0/200 samples classified correctly
# 1/1 [==============================] - 0s 108ms/step
# incorrect - Georgia_Giddings_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 44.66%
#
#  total accuracy is 0.00% = 0/201 samples classified correctly
# 1/1 [==============================] - 0s 112ms/step
# incorrect - Gholamreza_Aghazadeh_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/202 samples classified correctly
# 1/1 [==============================] - 0s 117ms/step
# incorrect - Gianna_Angelopoulos-Daskalaki_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 78.62%
#
#  total accuracy is 0.00% = 0/203 samples classified correctly
# 1/1 [==============================] - 0s 118ms/step
# incorrect - Gianna_Angelopoulos-Daskalaki_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/204 samples classified correctly
# 1/1 [==============================] - 0s 162ms/step
# incorrect - Gianna_Angelopoulos-Daskalaki_0003.jpg
# 	me     with probability of 0.03%
# 	not me with probability of 0.81%
#
#  total accuracy is 0.00% = 0/205 samples classified correctly
# 1/1 [==============================] - 0s 169ms/step
# incorrect - Glafcos_Clerides_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 35.65%
#
#  total accuracy is 0.00% = 0/206 samples classified correctly
# 1/1 [==============================] - 0s 121ms/step
# incorrect - Glafcos_Clerides_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/207 samples classified correctly
# 1/1 [==============================] - 0s 128ms/step
# incorrect - Glafcos_Clerides_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/208 samples classified correctly
# 1/1 [==============================] - 0s 115ms/step
# incorrect - Glafcos_Clerides_0004.jpg
# 	me     with probability of 0.17%
# 	not me with probability of 0.04%
#
#  total accuracy is 0.00% = 0/209 samples classified correctly
# 1/1 [==============================] - 0s 109ms/step
# incorrect - GL_Peiris_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 6.42%
#
#  total accuracy is 0.00% = 0/210 samples classified correctly
# 1/1 [==============================] - 0s 93ms/step
# incorrect - GL_Peiris_0002.jpg
# 	me     with probability of 0.04%
# 	not me with probability of 8.07%
#
#  total accuracy is 0.00% = 0/211 samples classified correctly
# 1/1 [==============================] - 0s 225ms/step
# incorrect - GL_Peiris_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 36.94%
#
#  total accuracy is 0.00% = 0/212 samples classified correctly
# 1/1 [==============================] - 0s 106ms/step
# incorrect - GL_Peiris_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.43%
#
#  total accuracy is 0.00% = 0/213 samples classified correctly
# 1/1 [==============================] - 0s 104ms/step
# incorrect - Gordon_Brown_0001.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 97.35%
#
#  total accuracy is 0.00% = 0/214 samples classified correctly
# 1/1 [==============================] - 0s 170ms/step
# incorrect - Gordon_Brown_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/215 samples classified correctly
# 1/1 [==============================] - 0s 158ms/step
# incorrect - Gordon_Brown_0003.jpg
# 	me     with probability of 0.09%
# 	not me with probability of 80.21%
#
#  total accuracy is 0.00% = 0/216 samples classified correctly
# 1/1 [==============================] - 0s 162ms/step
# incorrect - Gordon_Brown_0004.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 93.49%
#
#  total accuracy is 0.00% = 0/217 samples classified correctly
# 1/1 [==============================] - 0s 91ms/step
# incorrect - Gordon_Brown_0005.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
# ...
# 	me     with probability of 0.04%
# 	not me with probability of 99.82%
#
#  total accuracy is 0.00% = 0/222 samples classified correctly
# 1/1 [==============================] - 0s 298ms/step
# incorrect - Gordon_Brown_0010.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.98%
#
#  total accuracy is 0.00% = 0/223 samples classified correctly
# 1/1 [==============================] - 0s 149ms/step
# incorrect - Gordon_Brown_0011.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/224 samples classified correctly
# 1/1 [==============================] - 0s 266ms/step
# incorrect - Gordon_Brown_0012.jpg
# 	me     with probability of 0.03%
# 	not me with probability of 13.17%
#
#  total accuracy is 0.00% = 0/225 samples classified correctly
# 1/1 [==============================] - 0s 113ms/step
# incorrect - Gordon_Brown_0013.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.91%
#
#  total accuracy is 0.00% = 0/226 samples classified correctly
# 1/1 [==============================] - 0s 119ms/step
# incorrect - Gordon_Campbell_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.96%
#
#  total accuracy is 0.00% = 0/227 samples classified correctly
# 1/1 [==============================] - 0s 106ms/step
# incorrect - Gordon_Campbell_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 95.36%
#
#  total accuracy is 0.00% = 0/228 samples classified correctly
# 1/1 [==============================] - 0s 94ms/step
# incorrect - Jia_Qinglin_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 67.52%
#
#  total accuracy is 0.00% = 0/229 samples classified correctly
# 1/1 [==============================] - 0s 127ms/step
# incorrect - Jia_Qinglin_0002.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 94.55%
#
#  total accuracy is 0.00% = 0/230 samples classified correctly
# 1/1 [==============================] - 0s 99ms/step
# incorrect - Jim_Furyk_0001.jpg
# 	me     with probability of 0.78%
# 	not me with probability of 6.19%
#
#  total accuracy is 0.00% = 0/231 samples classified correctly
# 1/1 [==============================] - 0s 100ms/step
# incorrect - Jim_Furyk_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 95.88%
#
#  total accuracy is 0.00% = 0/232 samples classified correctly
# 1/1 [==============================] - 0s 199ms/step
# incorrect - Jim_Furyk_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.54%
#
#  total accuracy is 0.00% = 0/233 samples classified correctly
# 1/1 [==============================] - 0s 117ms/step
# incorrect - Jim_Furyk_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.99%
#
#  total accuracy is 0.00% = 0/234 samples classified correctly
# 1/1 [==============================] - 0s 92ms/step
# incorrect - Jim_Furyk_0005.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.74%
#
#  total accuracy is 0.00% = 0/235 samples classified correctly
# 1/1 [==============================] - 0s 180ms/step
# incorrect - Jim_Furyk_0006.jpg
# 	me     with probability of 41.79%
# 	not me with probability of 0.00%
#
#  total accuracy is 0.00% = 0/236 samples classified correctly
# 1/1 [==============================] - 0s 115ms/step
# incorrect - Maggie_Smith_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 29.20%
#
#  total accuracy is 0.00% = 0/237 samples classified correctly
# 1/1 [==============================] - 0s 108ms/step
# incorrect - Maggie_Smith_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 26.73%
#
#  total accuracy is 0.00% = 0/238 samples classified correctly
# 1/1 [==============================] - 0s 103ms/step
# incorrect - Marc_Leger_0001.jpg
# 	me     with probability of 1.27%
# 	not me with probability of 0.00%
#
#  total accuracy is 0.00% = 0/239 samples classified correctly
# 1/1 [==============================] - 0s 103ms/step
# incorrect - Michael_Jordan_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/240 samples classified correctly
# 1/1 [==============================] - 0s 147ms/step
# incorrect - Michael_Jordan_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/241 samples classified correctly
# 1/1 [==============================] - 0s 104ms/step
# incorrect - Michael_Jordan_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/242 samples classified correctly
# 1/1 [==============================] - 0s 147ms/step
# incorrect - Michael_Jordan_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.97%
#
#  total accuracy is 0.00% = 0/243 samples classified correctly
# 1/1 [==============================] - 0s 91ms/step
# incorrect - Michael_Kahn_0001.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 0.03%
#
#  total accuracy is 0.00% = 0/244 samples classified correctly
# 1/1 [==============================] - 0s 102ms/step
# incorrect - Michael_Michele_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/245 samples classified correctly
# 1/1 [==============================] - 0s 222ms/step
# incorrect - Michelle_Collins_0001.jpg
# 	me     with probability of 0.60%
# 	not me with probability of 2.61%
#
#  total accuracy is 0.00% = 0/246 samples classified correctly
# 1/1 [==============================] - 0s 85ms/step
# incorrect - Michelle_Collins_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/247 samples classified correctly
# 1/1 [==============================] - 0s 124ms/step
# incorrect - Mike_Carona_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 25.51%
#
#  total accuracy is 0.00% = 0/248 samples classified correctly
# 1/1 [==============================] - 0s 101ms/step
# incorrect - Mike_Scioscia_0001.jpg
# 	me     with probability of 21.49%
# 	not me with probability of 0.00%
#
#  total accuracy is 0.00% = 0/249 samples classified correctly
# 1/1 [==============================] - 0s 98ms/step
# incorrect - Mike_Scioscia_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/250 samples classified correctly
# 1/1 [==============================] - 0s 88ms/step
# incorrect - Mohamed_ElBaradei_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/251 samples classified correctly
# 1/1 [==============================] - 0s 121ms/step
# incorrect - Mohamed_ElBaradei_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/252 samples classified correctly
# 1/1 [==============================] - 0s 126ms/step
# incorrect - Mohamed_ElBaradei_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/253 samples classified correctly
# 1/1 [==============================] - 0s 126ms/step
# incorrect - Mohamed_ElBaradei_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/254 samples classified correctly
# 1/1 [==============================] - 0s 137ms/step
# incorrect - Mohamed_ElBaradei_0005.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 99.99%
#
#  total accuracy is 0.00% = 0/255 samples classified correctly
# 1/1 [==============================] - 0s 140ms/step
# incorrect - Mohamed_ElBaradei_0006.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/256 samples classified correctly
# 1/1 [==============================] - 0s 121ms/step
# incorrect - Mohamed_ElBaradei_0007.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 0.22%
#
#  total accuracy is 0.00% = 0/257 samples classified correctly
# 1/1 [==============================] - 0s 175ms/step
# incorrect - Mohamed_ElBaradei_0008.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 95.08%
#
#  total accuracy is 0.00% = 0/258 samples classified correctly
# 1/1 [==============================] - 0s 153ms/step
# incorrect - Mohamed_Hammam_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/259 samples classified correctly
# 1/1 [==============================] - 0s 99ms/step
# incorrect - Mohammed_Mehdi_Saleh_0001.jpg
# 	me     with probability of 4.09%
# 	not me with probability of 94.85%
#
#  total accuracy is 0.00% = 0/260 samples classified correctly
# 1/1 [==============================] - 0s 105ms/step
# incorrect - Naoto_Kan_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 51.55%
#
#  total accuracy is 0.00% = 0/261 samples classified correctly
# 1/1 [==============================] - 0s 102ms/step
# incorrect - Naoto_Kan_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 30.05%
#
#  total accuracy is 0.00% = 0/262 samples classified correctly
# 1/1 [==============================] - 0s 101ms/step
# incorrect - Naoto_Kan_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 97.58%
#
#  total accuracy is 0.00% = 0/263 samples classified correctly
# 1/1 [==============================] - 0s 127ms/step
# incorrect - Naoto_Kan_0004.jpg
# 	me     with probability of 4.92%
# 	not me with probability of 99.98%
#
#  total accuracy is 0.00% = 0/264 samples classified correctly
# 1/1 [==============================] - 0s 94ms/step
# incorrect - Nathan_Smith_0001.jpg
# 	me     with probability of 0.11%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/265 samples classified correctly
# 1/1 [==============================] - 0s 98ms/step
# incorrect - Nestor_Santillan_0001.jpg
# 	me     with probability of 0.79%
# 	not me with probability of 10.10%
#
#  total accuracy is 0.00% = 0/266 samples classified correctly
# 1/1 [==============================] - 0s 92ms/step
# incorrect - Nicholoas_DiMarzio_0001.jpg
# 	me     with probability of 81.84%
# 	not me with probability of 0.03%
#
#  total accuracy is 0.00% = 0/267 samples classified correctly
# 1/1 [==============================] - 0s 95ms/step
# incorrect - Nick_Reilly_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/268 samples classified correctly
# 1/1 [==============================] - 0s 96ms/step
# incorrect - Nicolas_Massu_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/269 samples classified correctly
# 1/1 [==============================] - 0s 88ms/step
# incorrect - Noel_Forgeard_0001.jpg
# 	me     with probability of 0.60%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/270 samples classified correctly
# 1/1 [==============================] - 0s 89ms/step
# incorrect - Osmond_Smith_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.99%
#
#  total accuracy is 0.00% = 0/271 samples classified correctly
# 1/1 [==============================] - 0s 93ms/step
# incorrect - Pascal_Lamy_0001.jpg
# 	me     with probability of 0.01%
# 	not me with probability of 0.01%
#
#  total accuracy is 0.00% = 0/272 samples classified correctly
# 1/1 [==============================] - 0s 264ms/step
# incorrect - Pascal_Lamy_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/273 samples classified correctly
# 1/1 [==============================] - 0s 116ms/step
# incorrect - Patrik_Kristiansson_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 98.95%
#
#  total accuracy is 0.00% = 0/274 samples classified correctly
# 1/1 [==============================] - 0s 137ms/step
# incorrect - Patsy_Kensit_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 68.98%
#
#  total accuracy is 0.00% = 0/275 samples classified correctly
# 1/1 [==============================] - 0s 135ms/step
# incorrect - Patty_Schnyder_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/276 samples classified correctly
# 1/1 [==============================] - 0s 111ms/step
# incorrect - Patty_Schnyder_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 97.87%
#
#  total accuracy is 0.00% = 0/277 samples classified correctly
# 1/1 [==============================] - 0s 133ms/step
# incorrect - Patty_Schnyder_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/278 samples classified correctly
# 1/1 [==============================] - 0s 126ms/step
# incorrect - Patty_Schnyder_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/279 samples classified correctly
# 1/1 [==============================] - 0s 120ms/step
# incorrect - Paul_Kelleher_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/280 samples classified correctly
# 1/1 [==============================] - 0s 127ms/step
# incorrect - Peggy_McGuinness_0001.jpg
# 	me     with probability of 37.88%
# 	not me with probability of 0.13%
#
#  total accuracy is 0.00% = 0/281 samples classified correctly
# 1/1 [==============================] - 0s 109ms/step
# incorrect - Peter_Shaw_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/282 samples classified correctly
# 1/1 [==============================] - 0s 115ms/step
# incorrect - Scott_Yates_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 99.99%
#
#  total accuracy is 0.00% = 0/283 samples classified correctly
# 1/1 [==============================] - 0s 129ms/step
# incorrect - Shane_Hmiel_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 98.58%
#
#  total accuracy is 0.00% = 0/284 samples classified correctly
# 1/1 [==============================] - 0s 305ms/step
# incorrect - Shaul_Mofaz_0001.jpg
# 	me     with probability of 0.02%
# 	not me with probability of 95.03%
#
#  total accuracy is 0.00% = 0/285 samples classified correctly
# 1/1 [==============================] - 0s 105ms/step
# incorrect - Shaul_Mofaz_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 78.42%
#
#  total accuracy is 0.00% = 0/286 samples classified correctly
# 1/1 [==============================] - 0s 222ms/step
# incorrect - Shaul_Mofaz_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/287 samples classified correctly
# 1/1 [==============================] - 0s 106ms/step
# incorrect - Tom_Welch_0001.jpg
# 	me     with probability of 0.70%
# 	not me with probability of 0.77%
#
#  total accuracy is 0.00% = 0/288 samples classified correctly
# 1/1 [==============================] - 0s 111ms/step
# incorrect - Tony_Bennett_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/289 samples classified correctly
# 1/1 [==============================] - 0s 114ms/step
# incorrect - Tony_Bennett_0002.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/290 samples classified correctly
# 1/1 [==============================] - 0s 209ms/step
# incorrect - Tony_Bennett_0003.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 97.61%
#
#  total accuracy is 0.00% = 0/291 samples classified correctly
# 1/1 [==============================] - 0s 105ms/step
# incorrect - Tony_Bennett_0004.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 94.07%
#
#  total accuracy is 0.00% = 0/292 samples classified correctly
# 1/1 [==============================] - 0s 114ms/step
# incorrect - Zorica_Radovic_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 98.90%
#
#  total accuracy is 0.00% = 0/293 samples classified correctly
# 1/1 [==============================] - 0s 103ms/step
# incorrect - Zydrunas_Ilgauskas_0001.jpg
# 	me     with probability of 0.00%
# 	not me with probability of 100.00%
#
#  total accuracy is 0.00% = 0/294 samples classified correctly

# %% [markdown]
# Test of particular image

# %%
test_path = 'datasets/face_dataset_test_images/me/IMG_9208.jpg'
test_image = keras.preprocessing.image.load_img(test_path, target_size=(img_height,img_width,3))
test_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>

# %%
test_image = keras.preprocessing.image.img_to_array(test_image) #from image to array
#shape from (250,250,3) to (1,250,250,3)
test_image = np.expand_dims(test_image, axis =0)
result = face_classifier.predict(test_image)

for index in range(num_classes):
    print("{:6} with propability of {:.2f}%".format(class_names[index], result[0][index] * 100))
# Out:
# 1/1 [==============================] - 0s 106ms/step
# me     with propability of 94.25%
# not_me with propability of 0.00%

# %% [markdown]
# Plotting

# %%
import matplotlib.pyplot as plt
dataset_size = [1, 2, 3, 4, 5, 10, 15, 20, 25]
training_time_per_epoch = [2, 4, 6, 8, 9, 19, 30, 35, 46]

fig=plt.figure(figsize=(8,4))
plt.plot(dataset_size, training_time_per_epoch, marker='o', label="Training Time")

plt.title("The Dependence of the training time on the dataset size", fontsize= '16')
plt.xlabel("The coefficient of the dataset increasing", fontsize = '14')
plt.ylabel("Training time for epoch, s", fontsize ='14')
plt.legend(loc='best')
plt.savefig('article/img/dataset_size_to_learning_time.jpg')
plt.show()

#the dependence of the training time (per epoch) on the dataset size is linear

# %%
dataset_size=[1, 2, 3, 4, 5, 10, 15, 20, 25]
val_loss=[0.8011, 0.2802, 0.2479, 0.2653, 0.191, 0.2191, 0.09886, 0.10429, 0.1322]
val_accuracy = [0.8276, 0.9138, 0.908, 0.8718, 0.911, 0.911, 0.9589, 0.9497, 0.9479]


fig = plt.figure(figsize=(8, 4))
plt.plot(dataset_size, val_loss, c="red", linewidth=2, marker='o', label="Validation Loss")
plt.plot(dataset_size, val_accuracy, c="green", linewidth=2, marker='o', label="Validation Accuracy")

plt.title("The Dependence of the Model Quality on the Dataset Size", fontsize='16')
plt.xlabel("The coefficient of the dataset increasing", fontsize='14')
plt.ylabel("Model Quality", fontsize='14')
plt.legend(loc='best')
plt.savefig('article/img/dataset_size_to_model_quality.jpg')
plt.show()
